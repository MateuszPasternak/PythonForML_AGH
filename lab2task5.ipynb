# %% [markdown]
# <a href="https://colab.research.google.com/github/MateuszPasternak/PythonForML_AGH/blob/main/lab2task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MateuszPasternak/PythonForML_AGH.git
# Out:
# Cloning into 'PythonForML_AGH'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 43 (delta 14), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (43/43), 9.13 KiB | 9.13 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# !mv -f temp/{.,}* .
# Out:
# mv: cannot stat 'temp/.*': No such file or directory
# mv: cannot stat 'temp/*': No such file or directory

# %%
# !rm -rf temp

# %%
# !touch utils.py

# %%
from utils import check_triangle
import numpy as np

# %%
numbers = np.random.rand(100,3)
